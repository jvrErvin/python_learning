# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# https://hu.wikipedia.org/wiki/Hisztogram

# %%
meres1 = np.random.randn(1000000)
meres2 = np.random.randint(1,7,100000)

print(meres1[0:10])
print(meres2[0:10])
# Out:
# [-0.49993485 -0.55050389  0.8171966  -1.46731299  0.60282976 -0.45006601
#  -0.46972336 -0.30159655 -0.8609197  -0.79422102]
# [3 4 3 4 1 1 1 3 5 5]

# %%
plt.hist(meres1, bins=10000, color='red', alpha=0.5)

plt.xlabel("x")
plt.ylabel("Frekvencia")
plt.show()

# %%
plt.hist(meres2, bins=30, color='red', alpha=0.5)

plt.xlabel("x")
plt.ylabel("Frekvencia")
plt.show()
